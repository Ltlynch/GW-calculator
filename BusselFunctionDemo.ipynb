# %% [markdown]
# # Goofing around with Bessel functions

# %%
from mpmath import *
import matplotlib.pyplot as plt
import numpy as np

# %%
# mp.dps = 15; mp.pretty = True

# %%
for i in np.arange(-1,2):
    y=[]
    print(i)
    for x in np.arange(0,10,.1):
        y.append(besselj(int(i),x))
    plt.plot(y)

plt.show()

for n in np.linspace(-1, 3, 4):
    print(type(float(besselj(n, .8*n))))
# Out:
# -1
# 0
# 1
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
